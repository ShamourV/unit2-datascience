# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# In this video we will be exploring python in  notebooks.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [11, 56, 9, 123, 12, 144]


plt.plot(y,x)

plt.ylabel("Shammy")
plt.xlabel("Wammy")
plt.title("You know who else likes charts >:)")
# Out:
# Text(0.5, 1.0, 'You know who else likes charts >:)')

# %%
labels = 'Mexicans', 'Domminicans', 'Jamaicans', 'Trinidadians'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
plt.title("Which is better from a unanomous vote")
# Out:
# Text(0.5, 1.0, 'Which is better from a unanomous vote')

# %%
y =[1,2,3,4,5]
x = [30,45,78,100,15]
plt.ylabel('shammy')
plt.xlabel('memes')
plt.title('be better')
# Out:
# Text(0.5, 1.0, 'be better')
